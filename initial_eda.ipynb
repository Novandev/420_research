# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
base_df = pd.read_csv('cannabis.csv')
base_df[:10]
#Just the first 10 here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     783
# --> 784         subarr = maybe_cast_to_datetime(arr, dtype)
#     785         # Take care in creating object arrays (but iterators are not
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1113         ):
# -> 1114             value = maybe_infer_to_datetimelike(value)
#    1115
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     910         v = [v]
# --> 911     v = np.array(v, copy=False)
#     912
#
# TypeError: 'Series' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#all seems well here, so lets go ahead and do some basic staints on the whole dataset

# %%
base_df['Rating']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# ~/anaconda3/lib/python3.7/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
print(ratings_array)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-026d5744f35f> in <module>
# ----> 1 print(ratings_array)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __repr__(self)
#    1616             min_rows=min_rows,
#    1617             max_rows=max_rows,
# -> 1618             length=show_dimensions,
#    1619         )
#    1620         result = buf.getvalue()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1682             max_rows=max_rows,
#    1683         )
# -> 1684         result = formatter.to_string()
#    1685
#    1686         # catch contract violations
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/formats/format.py in to_string(self)
#     311
# ...
